# %%
# !pip3 install keras==2.2.4
# Out:
# Requirement already satisfied: keras==2.2.4 in /usr/local/lib/python3.6/dist-packages (2.2.4)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.17.4)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.3.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (3.13)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (2.8.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.0.8)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.1.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.12.0)

# %%
import keras
from keras.layers import Conv2D, Conv3D, Flatten, Dense, Reshape, BatchNormalization
from keras.layers import Dropout, Input
from keras.models import Model
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint
from keras.utils import np_utils

from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, cohen_kappa_score

from operator import truediv

from plotly.offline import init_notebook_mode

import numpy as np
import matplotlib.pyplot as plt
import scipy.io as sio
import os

init_notebook_mode(connected=True)
# %matplotlib inline
import numpy as np
import random 
#import numpy as np
import matplotlib.pyplot as plt
import scipy.io as sio
from keras.models import Sequential, Model
from keras.layers import Convolution2D, MaxPooling2D, Conv3D, MaxPooling3D, ZeroPadding3D
from keras.layers import Activation, Dropout, Flatten, Dense, BatchNormalization, Input
from keras.utils.np_utils import to_categorical
from sklearn.decomposition import PCA
from keras.optimizers import Adam, SGD, Adadelta, RMSprop, Nadam
import keras.callbacks as kcallbacks
from keras.regularizers import l2
import time
import collections
from sklearn import metrics, preprocessing
from keras import backend as K
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
from google.colab import drive
drive.mount('/content/gdrive',force_remount=False)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
def loadData(name):
    data_path = '/content/gdrive/My Drive/GAMO_gen/'
    if name == 'IP':
        data = sio.loadmat(os.path.join(data_path, 'Indian_pines_corrected.mat'))['indian_pines_corrected']
        labels = sio.loadmat(os.path.join(data_path, 'Indian_pines_gt.mat'))['indian_pines_gt']
    elif name == 'SA':
        data = sio.loadmat(os.path.join(data_path, 'Salinas_corrected.mat'))['salinas_corrected']
        labels = sio.loadmat(os.path.join(data_path, 'Salinas_gt.mat'))['salinas_gt']
    elif name == 'PU':
        data = sio.loadmat(os.path.join(data_path, 'PaviaU.mat'))['paviaU']
        labels = sio.loadmat(os.path.join(data_path, 'PaviaU_gt.mat'))['paviaU_gt']
    elif name == 'KSC':
        data = sio.loadmat(os.path.join(data_path, 'KSC.mat'))['KSC']
        labels = sio.loadmat(os.path.join(data_path, 'KSC_gt.mat'))['KSC_gt']
    
    return data, labels

# %%
def splitTrainTestSet(X, y, testRatio, randomState=345):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=testRatio, random_state=randomState,
                                                        stratify=y)
    return X_train, X_test, y_train, y_test

# %%
def applyPCA(X, numComponents=75):
    newX = np.reshape(X, (-1, X.shape[2]))
    pca = PCA(n_components=numComponents, whiten=True)
    newX = pca.fit_transform(newX)
    newX = np.reshape(newX, (X.shape[0],X.shape[1], numComponents))
    return newX, pca

# %%
def padWithZeros(X, margin=2):
    newX = np.zeros((X.shape[0] + 2 * margin, X.shape[1] + 2* margin, X.shape[2]))
    x_offset = margin
    y_offset = margin
    newX[x_offset:X.shape[0] + x_offset, y_offset:X.shape[1] + y_offset, :] = X
    return newX

# %%
def createImageCubes(X, y, windowSize=5, removeZeroLabels = True):
    margin = int((windowSize - 1) / 2)
    zeroPaddedX = padWithZeros(X, margin=margin)
    # split patches
    patchesData = np.zeros((X.shape[0] * X.shape[1], windowSize, windowSize, X.shape[2]))
    patchesLabels = np.zeros((X.shape[0] * X.shape[1]))
    patchIndex = 0
    for r in range(margin, zeroPaddedX.shape[0] - margin):
        for c in range(margin, zeroPaddedX.shape[1] - margin):
            patch = zeroPaddedX[r - margin:r + margin + 1, c - margin:c + margin + 1]   
            patchesData[patchIndex, :, :, :] = patch
            patchesLabels[patchIndex] = y[r-margin, c-margin]
            patchIndex = patchIndex + 1
    if removeZeroLabels:
        patchesData = patchesData[patchesLabels>0,:,:,:]
        patchesLabels = patchesLabels[patchesLabels>0]
        patchesLabels -= 1
    return patchesData, patchesLabels

# %%
from google.colab import files
fl = files.upload() #upload the .py here from utils
import se_resnet8_max

def res4_model_ss():
    model_res4 = se_resnet8_max.SE_ResNet8((1, w, w, K),64, mp[d])
    # Set the hyper-parameters
    # m set according to paper to 2 * number of bits
    #my_custom_loss = lambda x,y: hashing_loss(x, y, m=2*32, alpha=0.001)

    # Compile the model
    #opt = keras.optimizers.adam(lr=0.1)
    #model_res4.compile(loss=my_custom_loss, optimizer=opt,metrics=['accuracy'])
    RMS = RMSprop(lr=0.001)
    # Let's train the model using RMSprop
    model_res4.compile(loss='categorical_crossentropy', optimizer=RMS, metrics=['accuracy'])

    return model_res4
# Out:
#      <input type="file" id="files-a02740ce-5649-497c-87a0-8cdb618c33dd" name="files[]" multiple disabled />
#      <output id="result-a02740ce-5649-497c-87a0-8cdb618c33dd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4185: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# input shape: (None, 15, 15, 5, 32)
# (?, 1, 1, 32)
# input shape: (None, 13, 13, 1, 32)
# (?, 1, 1, 32)
# (None, 13, 13, 32)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# call
# output
# (None, 13, 13, 32)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 15, 15, 15, 1 0
# __________________________________________________________________________________________________
# conv3d_1 (Conv3D)               (None, 15, 15, 5, 32 256         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 15, 15, 5, 32 128         conv3d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 15, 15, 5, 32 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv3d_2 (Conv3D)               (None, 15, 15, 5, 32 9248        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 15, 15, 5, 32 128         conv3d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 15, 15, 5, 32 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv3d_3 (Conv3D)               (None, 15, 15, 5, 32 9248        activation_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling3d_1 (Glo (None, 32)           0           conv3d_3[0][0]
# __________________________________________________________________________________________________
# global_max_pooling3d_1 (GlobalM (None, 32)           0           conv3d_3[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1, 1, 32)     0           global_average_pooling3d_1[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 1, 1, 32)     0           global_max_pooling3d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1, 1, 2)      64          reshape_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1, 1, 2)      64          reshape_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1, 1, 32)     64          dense_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1, 1, 32)     64          dense_3[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 15, 15, 5, 32 0           conv3d_3[0][0]
#                                                                  dense_2[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 15, 15, 5, 32 0           conv3d_3[0][0]
#                                                                  dense_4[0][0]
# __________________________________________________________________________________________________
# maximum_1 (Maximum)             (None, 15, 15, 5, 32 0           multiply_1[0][0]
#                                                                  multiply_2[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 15, 15, 5, 32 0           maximum_1[0][0]
#                                                                  conv3d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 15, 15, 5, 32 128         add_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 15, 15, 5, 32 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv3d_4 (Conv3D)               (None, 15, 15, 1, 12 20608       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 15, 15, 1, 12 512         conv3d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 15, 15, 1, 12 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 15, 15, 128,  0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv3d_5 (Conv3D)               (None, 13, 13, 1, 32 36896       reshape_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 13, 13, 1, 32 128         conv3d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 13, 13, 1, 32 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv3d_8 (Conv3D)               (None, 13, 13, 1, 32 1056        activation_5[0][0]
# __________________________________________________________________________________________________
# global_average_pooling3d_2 (Glo (None, 32)           0           conv3d_8[0][0]
# __________________________________________________________________________________________________
# global_max_pooling3d_2 (GlobalM (None, 32)           0           conv3d_8[0][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 1, 1, 32)     0           global_average_pooling3d_2[0][0]
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (None, 1, 1, 32)     0           global_max_pooling3d_2[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1, 1, 2)      64          reshape_4[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 1, 1, 2)      64          reshape_5[0][0]
# __________________________________________________________________________________________________
# conv3d_6 (Conv3D)               (None, 13, 13, 1, 32 9248        activation_5[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 1, 1, 32)     64          dense_5[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 1, 1, 32)     64          dense_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 13, 13, 1, 32 128         conv3d_6[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 13, 13, 1, 32 0           conv3d_8[0][0]
#                                                                  dense_6[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 13, 13, 1, 32 0           conv3d_8[0][0]
#                                                                  dense_8[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 13, 13, 1, 32 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# maximum_2 (Maximum)             (None, 13, 13, 1, 32 0           multiply_3[0][0]
#                                                                  multiply_4[0][0]
# __________________________________________________________________________________________________
# conv3d_7 (Conv3D)               (None, 13, 13, 1, 32 9248        activation_6[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 13, 13, 1, 32 0           maximum_2[0][0]
#                                                                  conv3d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 13, 13, 1, 32 128         add_2[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 13, 13, 1, 32 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 13, 13, 1, 32 128         activation_7[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 13, 13, 1, 32 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# reshape_6 (Reshape)             (None, 13, 13, 32)   0           activation_8[0][0]
# __________________________________________________________________________________________________
# bo_f__pooling_1 (BoF_Pooling)   (None, 64)           2112        reshape_6[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 64)           0           bo_f__pooling_1[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 16)           1040        dropout_1[0][0]
# ==================================================================================================
# Total params: 100,880
# Trainable params: 100,176
# Non-trainable params: 704
# __________________________________________________________________________________________________

# %%
import os
data_path = '/content/gdrive/My Drive/FuseNet' #Enter Desired output path here from utils
os.listdir(data_path)
# Out:
# ['1_NEW_KERNEL32_B_32_hashing15_19.hdf5']

# %%
from google.colab import files
fl = files.upload() #Upload the RAR File here
# !unrar e -y utils3.rar
import zeroPadding
import normalization
import doPCA
import modelStatsRecord
import averageAccuracy
import ssrn_SS_IN
# Out:
#      <input type="file" id="files-f95e85b5-59b3-4910-82bb-2ef0227f1c61" name="files[]" multiple disabled />
#      <output id="result-f95e85b5-59b3-4910-82bb-2ef0227f1c61">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# UNRAR 5.50 freeware      Copyright (c) 1993-2017 Alexander Roshal
#
#
# Extracting from utils3.rar
#
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# All OK

# %%
## GLOBAL VARIABLES
dataset = ['PU']#,'IP','PU']#
test_ratio = [0.8]#
windowSize = [15]#
mp = {'IP':16,'PU':9,'SA':16}

# %%
for d in dataset:
  for t in test_ratio:
    for w in windowSize:
      X , Y = loadData(d)
      K = 30 if d == 'IP' else 15
      X,pca = applyPCA(X,numComponents=K)
      X, Y = createImageCubes(X, Y, windowSize=w)
      X.shape, Y.shape
      sz = X.shape[0]//10
      Y = to_categorical(Y)
      X = X.reshape((X.shape[0],w,w,K,1))
      train_X, test_X, train_Y, test_Y = splitTrainTestSet(X, Y, t)
      val_X = test_X[:sz]
      test_X = test_X[sz:]
      val_Y = test_Y[:sz]
      test_Y = test_Y[sz:]
      KAPPA_RES_SS4 = []
      OA_RES_SS4 = []
      AA_RES_SS4 = []
      TRAINING_TIME_RES_SS4 = []
      TESTING_TIME_RES_SS4 = []
      ELEMENT_ACC_RES_SS4 = np.zeros((1, mp[d]))


      for index_iter in range(1):
          #try:
            print("# %d Iteration" % (index_iter + 1))

            # save the best validated model 

            best_weights_RES_path_ss4 = data_path+ '/' + str(
                index_iter + 1) + '_NEW_KERNEL32_B_32_hashing'+str(w)+'_'+str(int((1-t)*100))+'.hdf5'

            
            
            #Bilinear
            #
            #
            
            model_res4_SS_BN = res4_model_ss()

            earlyStopping6 = kcallbacks.EarlyStopping(monitor='val_loss', patience=200, verbose=1, mode='auto')
            saveBestModel6 = kcallbacks.ModelCheckpoint(best_weights_RES_path_ss4, monitor='val_loss', verbose=1,
                                                        save_best_only=True,
                                                        mode='auto')

            tic6 = time.clock()
            print(train_X.shape, test_X.shape)
            history_res4_SS_BN = model_res4_SS_BN.fit(
                train_X, train_Y,
                validation_data=(val_X, val_Y),
                batch_size=256,
                nb_epoch=50, shuffle=True, callbacks=[earlyStopping6,saveBestModel6])
            toc6 = time.clock()

            tic7 = time.clock()
            loss_and_metrics_res4_SS_BN = model_res4_SS_BN.evaluate(
                test_X, test_Y,
                batch_size=32)
            toc7 = time.clock()

            print('3D RES_SS4 without BN Training Time: ', toc6 - tic6)
            print('3D RES_SS4 without BN Test time:', toc7 - tic7)

            print('3D RES_SS4 without BN Test score:', loss_and_metrics_res4_SS_BN[0])
            print('3D RES_SS4 without BN Test accuracy:', loss_and_metrics_res4_SS_BN[1])

            print(history_res4_SS_BN.history.keys())

            pred_test_res4 = model_res4_SS_BN.predict(test_X).argmax(axis=1)
            collections.Counter(pred_test_res4)
            gt_test = test_Y
            overall_acc_res4 = metrics.accuracy_score(pred_test_res4, gt_test.argmax(axis=1))
            confusion_matrix_res4 = metrics.confusion_matrix(pred_test_res4, gt_test.argmax(axis=1))
            each_acc_res4, average_acc_res4 = averageAccuracy.AA_andEachClassAccuracy(confusion_matrix_res4)
            kappa = metrics.cohen_kappa_score(pred_test_res4, gt_test.argmax(axis=1))
            KAPPA_RES_SS4.append(kappa)
            OA_RES_SS4.append(overall_acc_res4)
            AA_RES_SS4.append(average_acc_res4)
            TRAINING_TIME_RES_SS4.append(toc6 - tic6)
            TESTING_TIME_RES_SS4.append(toc7 - tic7)
            ELEMENT_ACC_RES_SS4[index_iter, :] = each_acc_res4

            print("3D RESNET_SS4 without BN training finished.")
            print("# %d Iteration" % (index_iter + 1))

            modelStatsRecord.outputStats(KAPPA_RES_SS4, OA_RES_SS4, AA_RES_SS4, ELEMENT_ACC_RES_SS4,
                                     TRAINING_TIME_RES_SS4, TESTING_TIME_RES_SS4,
                                     history_res4_SS_BN, loss_and_metrics_res4_SS_BN, mp[d],
                                     data_path + '/IN_train_RESNET8_KERNEL64_20_B_32_Fuse_'+str(w)+'_'+str(int((1-t)*100))+'.txt',
                                     data_path + '/IN_train_RESNET8_KERNEL64_20_B_32_PU_element_9_Fuse_'+str(w)+'_'+str(int((1-t)*100))+'.txt')
# Out:
# # 1 Iteration
# input shape: (None, 15, 15, 5, 32)
# (?, 1, 1, 32)
# input shape: (None, 13, 13, 1, 32)
# (?, 1, 1, 32)
# (None, 13, 13, 32)
# call
# output
# (None, 13, 13, 32)
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 15, 15, 15, 1 0
# __________________________________________________________________________________________________
# conv3d_17 (Conv3D)              (None, 15, 15, 5, 32 256         input_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 15, 15, 5, 32 128         conv3d_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 15, 15, 5, 32 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv3d_18 (Conv3D)              (None, 15, 15, 5, 32 9248        activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 15, 15, 5, 32 128         conv3d_18[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 15, 15, 5, 32 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv3d_19 (Conv3D)              (None, 15, 15, 5, 32 9248        activation_18[0][0]
# __________________________________________________________________________________________________
# global_average_pooling3d_5 (Glo (None, 32)           0           conv3d_19[0][0]
# __________________________________________________________________________________________________
# global_max_pooling3d_5 (GlobalM (None, 32)           0           conv3d_19[0][0]
# __________________________________________________________________________________________________
# reshape_13 (Reshape)            (None, 1, 1, 32)     0           global_average_pooling3d_5[0][0]
# __________________________________________________________________________________________________
# reshape_14 (Reshape)            (None, 1, 1, 32)     0           global_max_pooling3d_5[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 1, 1, 2)      64          reshape_13[0][0]
# __________________________________________________________________________________________________
# dense_21 (Dense)                (None, 1, 1, 2)      64          reshape_14[0][0]
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 1, 1, 32)     64          dense_19[0][0]
# __________________________________________________________________________________________________
# dense_22 (Dense)                (None, 1, 1, 32)     64          dense_21[0][0]
# __________________________________________________________________________________________________
# multiply_9 (Multiply)           (None, 15, 15, 5, 32 0           conv3d_19[0][0]
#                                                                  dense_20[0][0]
# __________________________________________________________________________________________________
# multiply_10 (Multiply)          (None, 15, 15, 5, 32 0           conv3d_19[0][0]
#                                                                  dense_22[0][0]
# __________________________________________________________________________________________________
# maximum_5 (Maximum)             (None, 15, 15, 5, 32 0           multiply_9[0][0]
#                                                                  multiply_10[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 15, 15, 5, 32 0           maximum_5[0][0]
#                                                                  conv3d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 15, 15, 5, 32 128         add_5[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 15, 15, 5, 32 0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv3d_20 (Conv3D)              (None, 15, 15, 1, 12 20608       activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 15, 15, 1, 12 512         conv3d_20[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 15, 15, 1, 12 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# reshape_15 (Reshape)            (None, 15, 15, 128,  0           activation_20[0][0]
# __________________________________________________________________________________________________
# conv3d_21 (Conv3D)              (None, 13, 13, 1, 32 36896       reshape_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 13, 13, 1, 32 128         conv3d_21[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 13, 13, 1, 32 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv3d_24 (Conv3D)              (None, 13, 13, 1, 32 1056        activation_21[0][0]
# __________________________________________________________________________________________________
# global_average_pooling3d_6 (Glo (None, 32)           0           conv3d_24[0][0]
# __________________________________________________________________________________________________
# global_max_pooling3d_6 (GlobalM (None, 32)           0           conv3d_24[0][0]
# __________________________________________________________________________________________________
# reshape_16 (Reshape)            (None, 1, 1, 32)     0           global_average_pooling3d_6[0][0]
# __________________________________________________________________________________________________
# reshape_17 (Reshape)            (None, 1, 1, 32)     0           global_max_pooling3d_6[0][0]
# __________________________________________________________________________________________________
# dense_23 (Dense)                (None, 1, 1, 2)      64          reshape_16[0][0]
# __________________________________________________________________________________________________
# dense_25 (Dense)                (None, 1, 1, 2)      64          reshape_17[0][0]
# __________________________________________________________________________________________________
# conv3d_22 (Conv3D)              (None, 13, 13, 1, 32 9248        activation_21[0][0]
# __________________________________________________________________________________________________
# dense_24 (Dense)                (None, 1, 1, 32)     64          dense_23[0][0]
# __________________________________________________________________________________________________
# dense_26 (Dense)                (None, 1, 1, 32)     64          dense_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 13, 13, 1, 32 128         conv3d_22[0][0]
# __________________________________________________________________________________________________
# multiply_11 (Multiply)          (None, 13, 13, 1, 32 0           conv3d_24[0][0]
#                                                                  dense_24[0][0]
# __________________________________________________________________________________________________
# multiply_12 (Multiply)          (None, 13, 13, 1, 32 0           conv3d_24[0][0]
#                                                                  dense_26[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 13, 13, 1, 32 0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# maximum_6 (Maximum)             (None, 13, 13, 1, 32 0           multiply_11[0][0]
#                                                                  multiply_12[0][0]
# __________________________________________________________________________________________________
# conv3d_23 (Conv3D)              (None, 13, 13, 1, 32 9248        activation_22[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 13, 13, 1, 32 0           maximum_6[0][0]
#                                                                  conv3d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 13, 13, 1, 32 128         add_6[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 13, 13, 1, 32 0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 13, 13, 1, 32 128         activation_23[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 13, 13, 1, 32 0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# reshape_18 (Reshape)            (None, 13, 13, 32)   0           activation_24[0][0]
# __________________________________________________________________________________________________
# bo_f__pooling_3 (BoF_Pooling)   (None, 64)           2112        reshape_18[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 64)           0           bo_f__pooling_3[0][0]
# __________________________________________________________________________________________________
# dense_27 (Dense)                (None, 9)            585         dropout_3[0][0]
# ==================================================================================================
# Total params: 100,425
# Trainable params: 99,721
# Non-trainable params: 704
# __________________________________________________________________________________________________
# (8555, 15, 15, 15, 1) (29944, 15, 15, 15, 1)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:53: UserWarning:
#
# The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Train on 8555 samples, validate on 4277 samples
# Epoch 1/50
# 8555/8555 [==============================] - 5s 601us/step - loss: 7.7154 - acc: 0.0781 - val_loss: 12.1824 - val_acc: 0.0872
#
# Epoch 00001: val_loss improved from inf to 12.18237, saving model to /content/gdrive/My Drive/FuseNet/1_NEW_KERNEL32_B_32_hashing15_19.hdf5
# Epoch 2/50
# 8555/8555 [==============================] - 3s 308us/step - loss: 7.5840 - acc: 0.2354 - val_loss: 12.1764 - val_acc: 0.1136
#
# Epoch 00002: val_loss improved from 12.18237 to 12.17643, saving model to /content/gdrive/My Drive/FuseNet/1_NEW_KERNEL32_B_32_hashing15_19.hdf5
# Epoch 3/50
# 8555/8555 [==============================] - 3s 307us/step - loss: 5.2934 - acc: 0.3963 - val_loss: 7.3475 - val_acc: 0.4386
#
# Epoch 00003: val_loss improved from 12.17643 to 7.34753, saving model to /content/gdrive/My Drive/FuseNet/1_NEW_KERNEL32_B_32_hashing15_19.hdf5
# Epoch 4/50
# 8555/8555 [==============================] - 3s 307us/step - loss: 2.3370 - acc: 0.6096 - val_loss: 6.6623 - val_acc: 0.0311
#
# Epoch 00004: val_loss improved from 7.34753 to 6.66234, saving model to /content/gdrive/My Drive/FuseNet/1_NEW_KERNEL32_B_32_hashing15_19.hdf5
# Epoch 5/50
# 8555/8555 [==============================] - 3s 308us/step - loss: 1.0326 - acc: 0.7510 - val_loss: 1.6694 - val_acc: 0.6079
#
# Epoch 00005: val_loss improved from 6.66234 to 1.66938, saving model to /content/gdrive/My Drive/FuseNet/1_NEW_KERNEL32_B_32_hashing15_19.hdf5
# Epoch 6/50
# 8555/8555 [==============================] - 3s 307us/step - loss: 0.5971 - acc: 0.8489 - val_loss: 0.8053 - val_acc: 0.8057
#
# Epoch 00006: val_loss improved from 1.66938 to 0.80525, saving model to /content/gdrive/My Drive/FuseNet/1_NEW_KERNEL32_B_32_hashing15_19.hdf5
# Epoch 7/50
# 8555/8555 [==============================] - 3s 307us/step - loss: 0.4349 - acc: 0.8860 - val_loss: 2.0213 - val_acc: 0.6037
#
# Epoch 00007: val_loss did not improve from 0.80525
# Epoch 8/50
# 8555/8555 [==============================] - 3s 306us/step - loss: 0.3551 - acc: 0.9191 - val_loss: 0.2559 - val_acc: 0.9479
#
# Epoch 00008: val_loss improved from 0.80525 to 0.25586, saving model to /content/gdrive/My Drive/FuseNet/1_NEW_KERNEL32_B_32_hashing15_19.hdf5
# Epoch 9/50
# 8555/8555 [==============================] - 3s 308us/step - loss: 0.2896 - acc: 0.9319 - val_loss: 0.1812 - val_acc: 0.9764
#
# Epoch 00009: val_loss improved from 0.25586 to 0.18118, saving model to /content/gdrive/My Drive/FuseNet/1_NEW_KERNEL32_B_32_hashing15_19.hdf5
# Epoch 10/50
# 8555/8555 [==============================] - 3s 305us/step - loss: 0.2797 - acc: 0.9414 - val_loss: 0.1346 - val_acc: 0.9867
#
# Epoch 00010: val_loss improved from 0.18118 to 0.13464, saving model to /content/gdrive/My Drive/FuseNet/1_NEW_KERNEL32_B_32_hashing15_19.hdf5
# Epoch 11/50
# 8555/8555 [==============================] - 3s 305us/step - loss: 0.2109 - acc: 0.9578 - val_loss: 0.1136 - val_acc: 0.9911
#
# Epoch 00011: val_loss improved from 0.13464 to 0.11362, saving model to /content/gdrive/My Drive/FuseNet/1_NEW_KERNEL32_B_32_hashing15_19.hdf5
# Epoch 12/50
# 8555/8555 [==============================] - 3s 303us/step - loss: 0.1872 - acc: 0.9681 - val_loss: 0.0913 - val_acc: 0.9944
#
# Epoch 00012: val_loss improved from 0.11362 to 0.09132, saving model to /content/gdrive/My Drive/FuseNet/1_NEW_KERNEL32_B_32_hashing15_19.hdf5
# Epoch 13/50
# 8555/8555 [==============================] - 3s 307us/step - loss: 0.1609 - acc: 0.9737 - val_loss: 0.1030 - val_acc: 0.9906
#
# Epoch 00013: val_loss did not improve from 0.09132
# Epoch 14/50
# 8555/8555 [==============================] - 3s 308us/step - loss: 0.1745 - acc: 0.9708 - val_loss: 0.0925 - val_acc: 0.9928
#
# Epoch 00014: val_loss did not improve from 0.09132
# Epoch 15/50
# 8555/8555 [==============================] - 3s 307us/step - loss: 0.1448 - acc: 0.9784 - val_loss: 0.0851 - val_acc: 0.9942
#
# Epoch 00015: val_loss improved from 0.09132 to 0.08507, saving model to /content/gdrive/My Drive/FuseNet/1_NEW_KERNEL32_B_32_hashing15_19.hdf5
# Epoch 16/50
# 8555/8555 [==============================] - 3s 306us/step - loss: 0.1810 - acc: 0.9797 - val_loss: 0.0854 - val_acc: 0.9937
#
# Epoch 00016: val_loss did not improve from 0.08507
# Epoch 17/50
# 8555/8555 [==============================] - 3s 304us/step - loss: 0.1313 - acc: 0.9846 - val_loss: 0.0789 - val_acc: 0.9965
#
# Epoch 00017: val_loss improved from 0.08507 to 0.07887, saving model to /content/gdrive/My Drive/FuseNet/1_NEW_KERNEL32_B_32_hashing15_19.hdf5
# Epoch 18/50
# 8555/8555 [==============================] - 3s 305us/step - loss: 0.1479 - acc: 0.9812 - val_loss: 0.1110 - val_acc: 0.9832
#
# Epoch 00018: val_loss did not improve from 0.07887
# Epoch 19/50
# 8555/8555 [==============================] - 3s 304us/step - loss: 0.1048 - acc: 0.9909 - val_loss: 0.0757 - val_acc: 0.9965
#
# Epoch 00019: val_loss improved from 0.07887 to 0.07567, saving model to /content/gdrive/My Drive/FuseNet/1_NEW_KERNEL32_B_32_hashing15_19.hdf5
# Epoch 20/50
# 8555/8555 [==============================] - 3s 305us/step - loss: 0.1215 - acc: 0.9862 - val_loss: 0.0826 - val_acc: 0.9949
#
# Epoch 00020: val_loss did not improve from 0.07567
# Epoch 21/50
# 8555/8555 [==============================] - 3s 306us/step - loss: 0.1250 - acc: 0.9863 - val_loss: 0.0726 - val_acc: 0.9967
#
# Epoch 00021: val_loss improved from 0.07567 to 0.07260, saving model to /content/gdrive/My Drive/FuseNet/1_NEW_KERNEL32_B_32_hashing15_19.hdf5
# Epoch 22/50
# 8555/8555 [==============================] - 3s 305us/step - loss: 0.1012 - acc: 0.9904 - val_loss: 0.2129 - val_acc: 0.9425
#
# Epoch 00022: val_loss did not improve from 0.07260
# Epoch 23/50
# 8555/8555 [==============================] - 3s 304us/step - loss: 0.1003 - acc: 0.9906 - val_loss: 0.0942 - val_acc: 0.9883
#
# Epoch 00023: val_loss did not improve from 0.07260
# Epoch 24/50
# 8555/8555 [==============================] - 3s 304us/step - loss: 0.1134 - acc: 0.9876 - val_loss: 0.0740 - val_acc: 0.9970
#
# Epoch 00024: val_loss did not improve from 0.07260
# Epoch 25/50
# 8555/8555 [==============================] - 3s 306us/step - loss: 0.0904 - acc: 0.9918 - val_loss: 0.0722 - val_acc: 0.9974
#
# Epoch 00025: val_loss improved from 0.07260 to 0.07218, saving model to /content/gdrive/My Drive/FuseNet/1_NEW_KERNEL32_B_32_hashing15_19.hdf5
# Epoch 26/50
# 8555/8555 [==============================] - 3s 308us/step - loss: 0.1056 - acc: 0.9889 - val_loss: 0.3290 - val_acc: 0.9422
#
# Epoch 00026: val_loss did not improve from 0.07218
# Epoch 27/50
# 8555/8555 [==============================] - 3s 306us/step - loss: 0.0934 - acc: 0.9921 - val_loss: 0.0653 - val_acc: 0.9986
#
# Epoch 00027: val_loss improved from 0.07218 to 0.06526, saving model to /content/gdrive/My Drive/FuseNet/1_NEW_KERNEL32_B_32_hashing15_19.hdf5
# Epoch 28/50
# 8555/8555 [==============================] - 3s 306us/step - loss: 0.0981 - acc: 0.9912 - val_loss: 0.0685 - val_acc: 0.9972
#
# Epoch 00028: val_loss did not improve from 0.06526
# Epoch 29/50
# 8555/8555 [==============================] - 3s 307us/step - loss: 0.0845 - acc: 0.9933 - val_loss: 0.0711 - val_acc: 0.9970
#
# Epoch 00029: val_loss did not improve from 0.06526
# Epoch 30/50
# 8555/8555 [==============================] - 3s 310us/step - loss: 0.0855 - acc: 0.9932 - val_loss: 0.0661 - val_acc: 0.9979
#
# Epoch 00030: val_loss did not improve from 0.06526
# Epoch 31/50
# 8555/8555 [==============================] - 3s 312us/step - loss: 0.0870 - acc: 0.9922 - val_loss: 0.4311 - val_acc: 0.9528
#
# Epoch 00031: val_loss did not improve from 0.06526
# Epoch 32/50
# 8555/8555 [==============================] - 3s 307us/step - loss: 0.0939 - acc: 0.9919 - val_loss: 0.0637 - val_acc: 0.9979
#
# Epoch 00032: val_loss improved from 0.06526 to 0.06368, saving model to /content/gdrive/My Drive/FuseNet/1_NEW_KERNEL32_B_32_hashing15_19.hdf5
# Epoch 33/50
# 8555/8555 [==============================] - 3s 305us/step - loss: 0.0871 - acc: 0.9942 - val_loss: 0.0638 - val_acc: 0.9988
#
# Epoch 00033: val_loss did not improve from 0.06368
# Epoch 34/50
# 8555/8555 [==============================] - 3s 304us/step - loss: 0.0762 - acc: 0.9952 - val_loss: 0.0726 - val_acc: 0.9958
#
# Epoch 00034: val_loss did not improve from 0.06368
# Epoch 35/50
# 8555/8555 [==============================] - 3s 303us/step - loss: 0.1041 - acc: 0.9906 - val_loss: 0.0643 - val_acc: 0.9979
#
# Epoch 00035: val_loss did not improve from 0.06368
# Epoch 36/50
# 8555/8555 [==============================] - 3s 303us/step - loss: 0.0883 - acc: 0.9917 - val_loss: 0.1083 - val_acc: 0.9876
#
# Epoch 00036: val_loss did not improve from 0.06368
# Epoch 37/50
# 8555/8555 [==============================] - 3s 305us/step - loss: 0.0808 - acc: 0.9936 - val_loss: 0.0749 - val_acc: 0.9956
#
# Epoch 00037: val_loss did not improve from 0.06368
# Epoch 38/50
# 8555/8555 [==============================] - 3s 306us/step - loss: 0.0883 - acc: 0.9929 - val_loss: 0.0986 - val_acc: 0.9935
#
# Epoch 00038: val_loss did not improve from 0.06368
# Epoch 39/50
# 8555/8555 [==============================] - 3s 304us/step - loss: 0.0839 - acc: 0.9937 - val_loss: 0.0753 - val_acc: 0.9949
#
# Epoch 00039: val_loss did not improve from 0.06368
# Epoch 40/50
# 8555/8555 [==============================] - 3s 305us/step - loss: 0.0863 - acc: 0.9938 - val_loss: 0.0577 - val_acc: 0.9986
#
# Epoch 00040: val_loss improved from 0.06368 to 0.05767, saving model to /content/gdrive/My Drive/FuseNet/1_NEW_KERNEL32_B_32_hashing15_19.hdf5
# Epoch 41/50
# 8555/8555 [==============================] - 3s 305us/step - loss: 0.0668 - acc: 0.9964 - val_loss: 0.0649 - val_acc: 0.9953
#
# Epoch 00041: val_loss did not improve from 0.05767
# Epoch 42/50
# 8555/8555 [==============================] - 3s 302us/step - loss: 0.1018 - acc: 0.9899 - val_loss: 0.0745 - val_acc: 0.9942
#
# Epoch 00042: val_loss did not improve from 0.05767
# Epoch 43/50
# 8555/8555 [==============================] - 3s 302us/step - loss: 0.0765 - acc: 0.9943 - val_loss: 0.0590 - val_acc: 0.9984
#
# Epoch 00043: val_loss did not improve from 0.05767
# Epoch 44/50
# 8555/8555 [==============================] - 3s 303us/step - loss: 0.0647 - acc: 0.9960 - val_loss: 0.0611 - val_acc: 0.9974
#
# Epoch 00044: val_loss did not improve from 0.05767
# Epoch 45/50
# 8555/8555 [==============================] - 3s 305us/step - loss: 0.0678 - acc: 0.9961 - val_loss: 0.0569 - val_acc: 0.9981
#
# Epoch 00045: val_loss improved from 0.05767 to 0.05687, saving model to /content/gdrive/My Drive/FuseNet/1_NEW_KERNEL32_B_32_hashing15_19.hdf5
# Epoch 46/50
# 8555/8555 [==============================] - 3s 305us/step - loss: 0.0620 - acc: 0.9970 - val_loss: 0.0738 - val_acc: 0.9918
#
# Epoch 00046: val_loss did not improve from 0.05687
# Epoch 47/50
# 8555/8555 [==============================] - 3s 304us/step - loss: 0.0743 - acc: 0.9940 - val_loss: 0.0597 - val_acc: 0.9970
#
# Epoch 00047: val_loss did not improve from 0.05687
# Epoch 48/50
# 8555/8555 [==============================] - 3s 308us/step - loss: 0.0775 - acc: 0.9939 - val_loss: 0.0617 - val_acc: 0.9967
#
# Epoch 00048: val_loss did not improve from 0.05687
# Epoch 49/50
# 8555/8555 [==============================] - 3s 308us/step - loss: 0.0593 - acc: 0.9973 - val_loss: 0.1524 - val_acc: 0.9811
#
# Epoch 00049: val_loss did not improve from 0.05687
# Epoch 50/50
# 8555/8555 [==============================] - 3s 303us/step - loss: 0.0637 - acc: 0.9947 - val_loss: 0.0545 - val_acc: 0.9984
#
# Epoch 00050: val_loss improved from 0.05687 to 0.05453, saving model to /content/gdrive/My Drive/FuseNet/1_NEW_KERNEL32_B_32_hashing15_19.hdf5
# 29944/29944 [==============================] - 5s 155us/step
# 3D RES_SS4 without BN Training Time:  144.873248
# 3D RES_SS4 without BN Test time: 5.308132999999998
# 3D RES_SS4 without BN Test score: 0.0560191359282368
# 3D RES_SS4 without BN Test accuracy: 0.9984637990916377
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
# 3D RESNET_SS4 without BN training finished.
# # 1 Iteration
# Test score: 0.0560191359282368
# Test accuracy: 0.9984637990916377
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
